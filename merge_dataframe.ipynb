# %%
import bs4
from bs4 import BeautifulSoup
import requests
import pandas as pd
from time import sleep
from random import randint
import re

# %% [markdown]
# # 1st dataframe (yg lengkap)

# %%
df = pd.read_csv('GITHUB/has_exception/data/metacritic_puzzle_DETAILED_fix.csv')
# df = pd.read_csv('detail_temp/metacritic_role-playing_DETAILED_fix.csv')

# %%
df.index = np.arange(0, len(df))

# %%
df = df.iloc[:, 1:]

# %%
df
# Out:
#          id               publisher  \
# 0    108177                Nintendo
# 1    107746                Nintendo
# 2    106771                    SCEA
# 3    162962                 Mastiff
# 4    109524             Peter Stock
# ..      ...                     ...
# 466  146192  Majesco Games, Majesco
# 467  145769  Majesco Games, Majesco
# 468  145629               Zoo Games
# 469  115032                   Atlus
# 470  150703             G5 Software
#
#                                         publisher_url rating  \
# 0         https://www.metacritic.com/company/nintendo      E
# 1         https://www.metacritic.com/company/nintendo      E
# 2             https://www.metacritic.com/company/scea      E
# 3          https://www.metacritic.com/company/mastiff      E
# 4      https://www.metacritic.com/company/peter-stock    NaN
# ..                                                ...    ...
# 466  https://www.metacritic.com/company/majesco-games      E
# ...

# %%
df.duplicated(subset=['id', 'publisher', 'publisher_url', 'rating', 'developer', 'multigenre', 'player', 'metascore_how', 'metascore_review', 'userscore_how', 'userscore_review']).unique()
# Out:
# array([False])

# %% [markdown]
# # 2nd dataframe (yg tambahan)

# %%
df2 = pd.read_csv('revised/puzzle_REVISED_DETAIL_fix.csv')

# %%
df2 = df2.iloc[:, 1:]

# %%
df2.index = np.arange(0, len(df2))

# %%
df2
# Out:
#         id                   publisher  \
# 0   110584      Microsoft Game Studios
# 1   109491  Disney Interactive Studios
# 2   109257                    Nintendo
# 3   109195           Eidos Interactive
# 4   109601                      Midway
# 5   109599                      Midway
# 6   109004                 D3Publisher
# 7   109287                      Agetec
# 8   110205                        SCEA
# 9   109724                    Nintendo
# 10  109651      Majesco Games, Majesco
# 11  109231                 D3Publisher
# 12  108353      Majesco Games, Majesco
# 13  109574      Majesco Games, Majesco
# 14  109611                  MumboJumbo
# 15  108677                      Hudson
# 16  108815                 D3Publisher
# 17  109384                 D3Publisher
# 18  109687                         THQ
# 19  108184  Disney Interactive Studios
# 20  107711                 Codemasters
# 21  108719          Namco Bandai Games
# 22  108442                       Atlus
# ...

# %%
len(df2)
# Out:
# 24

# %%
df2.duplicated(subset=['id', 'publisher', 'publisher_url', 'rating', 'developer', 'multigenre', 'player', 'metascore_how', 'metascore_review', 'userscore_how', 'userscore_review']).unique()
# Out:
# array([False])

# %%
df_merged = pd.concat([df, df2], axis=0, join="outer")

# %%
import numpy as np
df_merged.index = np.arange(0, len(df_merged))

# %%
df_merged
# Out:
#          id                   publisher  \
# 0    108177                    Nintendo
# 1    107746                    Nintendo
# 2    106771                        SCEA
# 3    162962                     Mastiff
# 4    109524                 Peter Stock
# ..      ...                         ...
# 490  108184  Disney Interactive Studios
# 491  107711                 Codemasters
# 492  108719          Namco Bandai Games
# 493  108442                       Atlus
# 494  108635            O3 Entertainment
#
#                                          publisher_url rating  \
# 0          https://www.metacritic.com/company/nintendo      E
# 1          https://www.metacritic.com/company/nintendo      E
# 2              https://www.metacritic.com/company/scea      E
# 3           https://www.metacritic.com/company/mastiff      E
# 4       https://www.metacritic.com/company/peter-stock    NaN
# ..                                                 ...    ...
# ...

# %%
length = len(df) + len(df2)
length
# Out:
# 495

# %%
df_merged['id'].unique()
# Out:
# array([108177, 107746, 106771, 162962, 109524, 107706, 107722, 107578,
#        107536, 107723, 107134, 107738, 108674, 107288, 107105, 107483,
#        107637, 107684, 105679, 162928, 107592, 107602, 107609, 107196,
#        162272, 106641, 104445, 104139, 162587, 105915, 105214, 105570,
#        161017, 105784, 105219, 104133, 105223, 105267, 105153, 162455,
#        162439, 162279, 162537, 163368, 162282, 162401, 103333, 162152,
#        103089, 103253, 162180, 162185, 161916, 161694, 161686, 161816,
#        161760, 161762, 161761, 161435, 161199, 163183, 161501, 101808,
#        161237, 102465, 161215, 161489, 161545, 102243, 161644, 161488,
#        163166, 161146, 161609, 163250, 161421, 102085, 161420, 102147,
#        101687, 161348, 161300, 161290, 161094, 160986, 101432, 160980,
#        101445, 160924, 101361, 101148, 161950, 160827, 160765, 111741,
#        107451, 110604, 110605, 112056, 111705, 109039, 111995, 111942,
# ...

# %%
len(df_merged['id'].unique())
# Out:
# 495

# %%
df_merged.duplicated(subset=['id', 'publisher', 'publisher_url', 'rating', 'developer', 'multigenre', 'player', 'metascore_how', 'metascore_review', 'userscore_how', 'userscore_review']).unique()
# Out:
# array([False])

# %%
df_merged.to_csv('GITHUB/detail_fix2/metacritic_puzzle_DETAILED_fix.csv')
# df_merged.to_csv('detail_temp/metacritic_role-playing_DETAILED_fix.csv')

# %% [markdown]
# ==================================================================================================

# %% [markdown]
# ### numpang

# %%
# x = pd.read_csv('GITHUB/detail_fix2/metacritic_third-person_DETAILED_fix.csv')

# %%
# x
# Out:
#       Unnamed: 0      id                           publisher  \
# 0              0  161682                   Bam Entertainment
# 1              1  163154                               Namco
# 2              2  161338                    Simon & Schuster
# 3              3  102149                           LucasArts
# 4              4  161186                          Activision
# ...          ...     ...                                 ...
# 1290           7  529622                         D3Publisher
# 1291           8  534152  Microsoft Game Studios, THQ Nordic
# 1292           9  524955                  Bandai Namco Games
# 1293          10  510717                           Rebellion
# 1294          11  574158                   Xbox Game Studios
#
#                                           publisher_url rating  \
# 0     https://www.metacritic.com/company/bam-enterta...      T
# 1              https://www.metacritic.com/company/namco      M
# ...

# %%
# x = x.iloc[:, 1:]

# %%
# x
# Out:
#           id                           publisher  \
# 0     161682                   Bam Entertainment
# 1     163154                               Namco
# 2     161338                    Simon & Schuster
# 3     102149                           LucasArts
# 4     161186                          Activision
# ...      ...                                 ...
# 1290  529622                         D3Publisher
# 1291  534152  Microsoft Game Studios, THQ Nordic
# 1292  524955                  Bandai Namco Games
# 1293  510717                           Rebellion
# 1294  574158                   Xbox Game Studios
#
#                                           publisher_url rating  \
# 0     https://www.metacritic.com/company/bam-enterta...      T
# 1              https://www.metacritic.com/company/namco      M
# 2     https://www.metacritic.com/company/simon-schuster      T
# 3          https://www.metacritic.com/company/lucasarts      T
# ...

# %%
# import numpy as np
# x.index = np.arange(0, len(x))

# %%
# x
# Out:
#           id                           publisher  \
# 0     161682                   Bam Entertainment
# 1     163154                               Namco
# 2     161338                    Simon & Schuster
# 3     102149                           LucasArts
# 4     161186                          Activision
# ...      ...                                 ...
# 1290  529622                         D3Publisher
# 1291  534152  Microsoft Game Studios, THQ Nordic
# 1292  524955                  Bandai Namco Games
# 1293  510717                           Rebellion
# 1294  574158                   Xbox Game Studios
#
#                                           publisher_url rating  \
# 0     https://www.metacritic.com/company/bam-enterta...      T
# 1              https://www.metacritic.com/company/namco      M
# 2     https://www.metacritic.com/company/simon-schuster      T
# 3          https://www.metacritic.com/company/lucasarts      T
# ...

# %%
# x.to_csv('GITHUB/detail_fix2/metacritic_third-person_DETAILED_fix.csv')

# %%
# x
# Out:
#           id                           publisher  \
# 0     161682                   Bam Entertainment
# 1     163154                               Namco
# 2     161338                    Simon & Schuster
# 3     102149                           LucasArts
# 4     161186                          Activision
# ...      ...                                 ...
# 1290  529622                         D3Publisher
# 1291  534152  Microsoft Game Studios, THQ Nordic
# 1292  524955                  Bandai Namco Games
# 1293  510717                           Rebellion
# 1294  574158                   Xbox Game Studios
#
#                                           publisher_url rating  \
# 0     https://www.metacritic.com/company/bam-enterta...      T
# 1              https://www.metacritic.com/company/namco      M
# 2     https://www.metacritic.com/company/simon-schuster      T
# 3          https://www.metacritic.com/company/lucasarts      T
# ...
